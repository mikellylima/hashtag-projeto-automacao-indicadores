# %% [markdown]
# ### Passo 1 - Importar Arquivos e Bibliotecas

# %%
# Importar bibliotecas
import pandas as pd
import smtplib
from email.message import EmailMessage
import mimetypes
from pathlib import Path

# %%
# Importar bases de dados
emails = pd.read_excel(r'bases-de-dados/Emails.xlsx')
lojas = pd.read_csv(r'bases-de-dados/Lojas.csv', encoding='latin1', sep=';')
vendas = pd.read_excel(r'bases-de-dados/Vendas.xlsx')
display(emails)
display(lojas)
display(vendas)
# Out:
#                                 Loja      Gerente  \
# 0                 Iguatemi Esplanada       Helena
# 1               Shopping Midway Mall        Alice
# 2                     Norte Shopping        Laura
# 3        Shopping Iguatemi Fortaleza      Manuela
# 4           Shopping União de Osasco    Valentina
# 5         Shopping Center Interlagos       Sophia
# 6                     Rio Mar Recife     Isabella
# 7                  Salvador Shopping      Heloisa
# 8         Rio Mar Shopping Fortaleza        Luiza
# 9   Shopping Center Leste Aricanduva        Julia
# 10                 Ribeirão Shopping       Lorena
# 11                  Shopping Morumbi        Livia
# 12         Parque Dom Pedro Shopping  Maria Luiza
# 13               Bourbon Shopping SP      Cecilia
# 14       Palladium Shopping Curitiba         Eloa
# 15         Passei das Águas Shopping       Miguel
# 16        Center Shopping Uberlândia       Arthur
# 17                   Shopping Recife       Heitor
# 18               Shopping Vila Velha     Bernardo
# 19                Shopping SP Market         Davi
# 20                 Shopping Eldorado         Theo
# 21               Shopping Ibirapuera      Lorenzo
# 22      Novo Shopping Ribeirão Preto      Gabriel
# 23                 Iguatemi Campinas        Pedro
# 24                    Shopping Barra     Benjamin
# 25                         Diretoria    Diretoria
#
#                                         E-mail
# 0        pythonimpressionador+helena@gmail.com
# 1         pythonimpressionador+alice@gmail.com
# 2         pythonimpressionador+laura@gmail.com
# 3       pythonimpressionador+manuela@gmail.com
# 4     pythonimpressionador+valentina@gmail.com
# 5        pythonimpressionador+sophia@gmail.com
# 6      pythonimpressionador+isabella@gmail.com
# 7       pythonimpressionador+heloisa@gmail.com
# 8         pythonimpressionador+luiza@gmail.com
# 9         pythonimpressionador+julia@gmail.com
# 10       pythonimpressionador+lorena@gmail.com
# 11        pythonimpressionador+livia@gmail.com
# 12  pythonimpressionador+maria_luiza@gmail.com
# 13      pythonimpressionador+cecilia@gmail.com
# 14         pythonimpressionador+eloa@gmail.com
# 15       pythonimpressionador+miguel@gmail.com
# 16       pythonimpressionador+arthur@gmail.com
# 17       pythonimpressionador+heitor@gmail.com
# 18     pythonimpressionador+bernardo@gmail.com
# 19         pythonimpressionador+davi@gmail.com
# 20         pythonimpressionador+theo@gmail.com
# 21      pythonimpressionador+lorenzo@gmail.com
# 22      pythonimpressionador+gabriel@gmail.com
# 23        pythonimpressionador+pedro@gmail.com
# 24     pythonimpressionador+benjamin@gmail.com
# 25    pythonimpressionador+diretoria@gmail.com
#     ID Loja                              Loja
# 0         1                Iguatemi Esplanada
# 1         2              Shopping Midway Mall
# 2         3                    Norte Shopping
# 3         4       Shopping Iguatemi Fortaleza
# 4         5          Shopping União de Osasco
# 5         6        Shopping Center Interlagos
# 6         7                    Rio Mar Recife
# 7         8                 Salvador Shopping
# 8         9        Rio Mar Shopping Fortaleza
# 9        10  Shopping Center Leste Aricanduva
# 10       11                 Ribeirão Shopping
# 11       12                  Shopping Morumbi
# 12       13         Parque Dom Pedro Shopping
# 13       14               Bourbon Shopping SP
# 14       15       Palladium Shopping Curitiba
# 15       16         Passei das Águas Shopping
# 16       17        Center Shopping Uberlândia
# 17       18                   Shopping Recife
# 18       19               Shopping Vila Velha
# 19       20                Shopping SP Market
# 20       21                 Shopping Eldorado
# 21       22               Shopping Ibirapuera
# 22       23      Novo Shopping Ribeirão Preto
# 23       24                 Iguatemi Campinas
# 24       25                    Shopping Barra
#         Código Venda       Data  ID Loja           Produto  Quantidade  \
# 0                  1 2019-01-01        1    Sapato Estampa           1
# 1                  1 2019-01-01        1          Camiseta           2
# 2                  1 2019-01-01        1     Sapato Xadrez           1
# 3                  2 2019-01-02        3           Relógio           3
# 4                  2 2019-01-02        3      Chinelo Liso           1
# ...              ...        ...      ...               ...         ...
# 100994         69996 2019-12-26       17    Short Listrado           2
# 100995         69996 2019-12-26       17           Mochila           4
# 100996         69996 2019-12-26       17  Pulseira Estampa           1
# 100997         69997 2019-12-26       11   Camisa Listrado           1
# 100998         69997 2019-12-26       11       Short Linho           2
#
#         Valor Unitário  Valor Final
# 0                  358          358
# 1                  180          360
# 2                  368          368
# 3                  200          600
# 4                   71           71
# ...                ...          ...
# 100994             102          204
# 100995             270         1080
# 100996              87           87
# 100997             108          108
# 100998             133          266
#
# [100999 rows x 7 columns]

# %% [markdown]
# ### Passo 2 - Definir Criar uma Tabela para cada Loja e Definir o dia do Indicador

# %%
# Incluir nome da loja em vendas
vendas = vendas.merge(lojas, on='ID Loja')
display(vendas)
# Out:
#         Código Venda       Data  ID Loja           Produto  Quantidade  \
# 0                  1 2019-01-01        1    Sapato Estampa           1
# 1                  1 2019-01-01        1          Camiseta           2
# 2                  1 2019-01-01        1     Sapato Xadrez           1
# 3                  2 2019-01-02        3           Relógio           3
# 4                  2 2019-01-02        3      Chinelo Liso           1
# ...              ...        ...      ...               ...         ...
# 100994         69996 2019-12-26       17    Short Listrado           2
# 100995         69996 2019-12-26       17           Mochila           4
# 100996         69996 2019-12-26       17  Pulseira Estampa           1
# 100997         69997 2019-12-26       11   Camisa Listrado           1
# 100998         69997 2019-12-26       11       Short Linho           2
#
#         Valor Unitário  Valor Final                        Loja
# 0                  358          358          Iguatemi Esplanada
# 1                  180          360          Iguatemi Esplanada
# 2                  368          368          Iguatemi Esplanada
# 3                  200          600              Norte Shopping
# 4                   71           71              Norte Shopping
# ...                ...          ...                         ...
# 100994             102          204  Center Shopping Uberlândia
# 100995             270         1080  Center Shopping Uberlândia
# 100996              87           87  Center Shopping Uberlândia
# 100997             108          108           Ribeirão Shopping
# 100998             133          266           Ribeirão Shopping
#
# [100999 rows x 8 columns]

# %%
# Separando as lojas em um dicionário
dicionario_lojas = {}
for loja in lojas['Loja']:
    dicionario_lojas[loja] = vendas.loc[vendas['Loja']==loja, :]

display(dicionario_lojas)
# Out:
# {'Iguatemi Esplanada':         Código Venda       Data  ID Loja                 Produto  Quantidade  \
#  0                  1 2019-01-01        1          Sapato Estampa           1
#  1                  1 2019-01-01        1                Camiseta           2
#  2                  1 2019-01-01        1           Sapato Xadrez           1
#  26                21 2019-01-02        1  Camisa Gola V Listrado           2
#  44                34 2019-01-02        1         Sapato Listrado           1
#  ...              ...        ...      ...                     ...         ...
#  100847         69899 2019-12-25        1           Sapato Xadrez           4
#  100854         69903 2019-12-25        1              Terno Liso           5
#  100894         69928 2019-12-25        1                    Meia           1
#  100920         69944 2019-12-25        1            Gorro Xadrez           5
#  100921         69944 2019-12-25        1           Sapato Xadrez           2
#
#          Valor Unitário  Valor Final                Loja
#  0                  358          358  Iguatemi Esplanada
#  1                  180          360  Iguatemi Esplanada
#  2                  368          368  Iguatemi Esplanada
#  26                 116          232  Iguatemi Esplanada
#  44                 363          363  Iguatemi Esplanada
#  ...                ...          ...                 ...
#  100847             368         1472  Iguatemi Esplanada
#  100854             720         3600  Iguatemi Esplanada
#  100894              30           30  Iguatemi Esplanada
#  100920              85          425  Iguatemi Esplanada
#  100921             368          736  Iguatemi Esplanada
#
#  [3980 rows x 8 columns],
#  'Shopping Midway Mall':         Código Venda       Data  ID Loja        Produto  Quantidade  \
#  18                12 2019-01-02        2   Short Xadrez           4
#  19                12 2019-01-02        2     Sunga Liso           2
#  42                33 2019-01-02        2         Camisa           1
#  43                33 2019-01-02        2    Meia Xadrez           3
#  66                48 2019-01-02        2    Cueca Linho           2
#  ...              ...        ...      ...            ...         ...
#  100876         69914 2019-12-25        2     Short Liso           2
#  100877         69914 2019-12-25        2          Cinto           5
#  100883         69919 2019-12-25        2   Cinto Xadrez           3
#  100895         69929 2019-12-25        2  Meia Listrado           2
#  100991         69994 2019-12-26        2          Calça           1
#
#          Valor Unitário  Valor Final                  Loja
#  18                 100          400  Shopping Midway Mall
#  19                 114          228  Shopping Midway Mall
#  42                 100          100  Shopping Midway Mall
#  43                  41          123  Shopping Midway Mall
#  66                  93          186  Shopping Midway Mall
#  ...                ...          ...                   ...
#  100876             108          216  Shopping Midway Mall
#  100877             200         1000  Shopping Midway Mall
#  100883             215          645  Shopping Midway Mall
#  100895              37           74  Shopping Midway Mall
#  100991             170          170  Shopping Midway Mall
#
#  [3837 rows x 8 columns],
#  'Norte Shopping':         Código Venda       Data  ID Loja                 Produto  Quantidade  \
#  3                  2 2019-01-02        3                 Relógio           3
#  4                  2 2019-01-02        3            Chinelo Liso           1
#  8                  7 2019-01-02        3  Camisa Gola V Listrado           1
#  9                  7 2019-01-02        3             Camisa Liso           1
#  100               73 2019-01-02        3            Cueca Xadrez           5
#  ...              ...        ...      ...                     ...         ...
#  100830         69888 2019-12-25        3             Tênis Linho           1
#  100878         69916 2019-12-25        3                   Terno           2
#  100945         69962 2019-12-25        3              Meia Linho           2
#  100968         69976 2019-12-26        3            Tênis Xadrez           1
#  100969         69976 2019-12-26        3                  Casaco           4
#
#          Valor Unitário  Valor Final            Loja
#  3                  200          600  Norte Shopping
#  4                   71           71  Norte Shopping
#  8                  116          116  Norte Shopping
#  9                  105          105  Norte Shopping
#  100                 60          300  Norte Shopping
#  ...                ...          ...             ...
#  100830             294          294  Norte Shopping
#  100878             700         1400  Norte Shopping
#  100945              78          156  Norte Shopping
#  100968             259          259  Norte Shopping
#  100969             250         1000  Norte Shopping
#
#  [4179 rows x 8 columns],
#  'Shopping Iguatemi Fortaleza':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  96                71 2019-01-02        4           Relógio           4
#  97                71 2019-01-02        4  Relógio Listrado           4
#  144              111 2019-01-02        4        Cueca Liso           2
#  260              187 2019-01-02        4        Short Liso           2
#  344              248 2019-01-03        4     Pulseira Liso           2
#  ...              ...        ...      ...               ...         ...
#  100867         69910 2019-12-25        4      Chinelo Liso           2
#  100868         69910 2019-12-25        4  Relógio Listrado           2
#  100955         69968 2019-12-25        4        Polo Linho           1
#  100956         69968 2019-12-25        4    Camisa Estampa           3
#  100957         69968 2019-12-25        4        Cueca Liso           5
#
#          Valor Unitário  Valor Final                         Loja
#  96                 200          800  Shopping Iguatemi Fortaleza
#  97                 218          872  Shopping Iguatemi Fortaleza
#  144                 69          138  Shopping Iguatemi Fortaleza
#  260                108          216  Shopping Iguatemi Fortaleza
#  344                 87          174  Shopping Iguatemi Fortaleza
#  ...                ...          ...                          ...
#  100867              71          142  Shopping Iguatemi Fortaleza
#  100868             218          436  Shopping Iguatemi Fortaleza
#  100955             176          176  Shopping Iguatemi Fortaleza
#  100956             113          339  Shopping Iguatemi Fortaleza
#  100957              69          345  Shopping Iguatemi Fortaleza
#
#  [4021 rows x 8 columns],
#  'Shopping União de Osasco':         Código Venda       Data  ID Loja          Produto  Quantidade  \
#  32                26 2019-01-02        5          Chinelo           2
#  55                42 2019-01-02        5          Chinelo           2
#  71                54 2019-01-02        5     Cueca Xadrez           1
#  72                54 2019-01-02        5      Cueca Linho           2
#  73                54 2019-01-02        5        Meia Liso           5
#  ...              ...        ...      ...              ...         ...
#  100915         69940 2019-12-25        5      Polo Xadrez           2
#  100916         69940 2019-12-25        5   Camisa Estampa           2
#  100973         69979 2019-12-26        5    Camisa Gola V           2
#  100974         69979 2019-12-26        5  Mochila Estampa           3
#  100975         69979 2019-12-26        5       Polo Linho           1
#
#          Valor Unitário  Valor Final                      Loja
#  32                  60          120  Shopping União de Osasco
#  55                  60          120  Shopping União de Osasco
#  71                  60           60  Shopping União de Osasco
#  72                  93          186  Shopping União de Osasco
#  73                  38          190  Shopping União de Osasco
#  ...                ...          ...                       ...
#  100915             142          284  Shopping União de Osasco
#  100916             113          226  Shopping União de Osasco
#  100973             100          200  Shopping União de Osasco
#  100974             277          831  Shopping União de Osasco
#  100975             176          176  Shopping União de Osasco
#
#  [3995 rows x 8 columns],
#  'Shopping Center Interlagos':         Código Venda       Data  ID Loja              Produto  Quantidade  \
#  25                20 2019-01-02        6         Mochila Liso           1
#  145              112 2019-01-02        6       Calça Listrado           2
#  146              112 2019-01-02        6  Camisa Gola V Linho           2
#  179              135 2019-01-02        6       Mochila Xadrez           3
#  180              135 2019-01-02        6       Camisa Estampa           1
#  ...              ...        ...      ...                  ...         ...
#  100863         69907 2019-12-25        6             Pulseira           1
#  100892         69926 2019-12-25        6           Short Liso           1
#  100893         69926 2019-12-25        6          Calça Linho           1
#  100971         69978 2019-12-26        6         Gorro Xadrez           2
#  100972         69978 2019-12-26        6        Terno Estampa           2
#
#          Valor Unitário  Valor Final                        Loja
#  25                 276          276  Shopping Center Interlagos
#  145                181          362  Shopping Center Interlagos
#  146                145          290  Shopping Center Interlagos
#  179                283          849  Shopping Center Interlagos
#  180                113          113  Shopping Center Interlagos
#  ...                ...          ...                         ...
#  100863              70           70  Shopping Center Interlagos
#  100892             108          108  Shopping Center Interlagos
#  100893             211          211  Shopping Center Interlagos
#  100971              85          170  Shopping Center Interlagos
#  100972             706         1412  Shopping Center Interlagos
#
#  [4021 rows x 8 columns],
#  'Rio Mar Recife':         Código Venda       Data  ID Loja                 Produto  Quantidade  \
#  62                46 2019-01-02        7                  Camisa           1
#  63                46 2019-01-02        7              Calça Liso           2
#  64                46 2019-01-02        7                   Cinto           1
#  113               87 2019-01-02        7          Camisa Estampa           1
#  142              109 2019-01-02        7  Camisa Gola V Listrado           3
#  ...              ...        ...      ...                     ...         ...
#  100858         69905 2019-12-25        7        Mochila Listrado           2
#  100859         69905 2019-12-25        7           Camisa Xadrez           3
#  100860         69905 2019-12-25        7              Tênis Liso           3
#  100929         69954 2019-12-25        7                 Chinelo           3
#  100930         69954 2019-12-25        7         Casaco Listrado           3
#
#          Valor Unitário  Valor Final            Loja
#  62                 100          100  Rio Mar Recife
#  63                 190          380  Rio Mar Recife
#  64                 200          200  Rio Mar Recife
#  113                113          113  Rio Mar Recife
#  142                116          348  Rio Mar Recife
#  ...                ...          ...             ...
#  100858             275          550  Rio Mar Recife
#  100859             105          315  Rio Mar Recife
#  100860             266          798  Rio Mar Recife
#  100929              60          180  Rio Mar Recife
#  100930             269          807  Rio Mar Recife
#
#  [4099 rows x 8 columns],
#  'Salvador Shopping':         Código Venda       Data  ID Loja              Produto  Quantidade  \
#  106               81 2019-01-02        8         Cueca Xadrez           1
#  166              126 2019-01-02        8       Camisa Estampa           1
#  183              138 2019-01-02        8       Pulseira Linho           5
#  244              177 2019-01-02        8          Camisa Liso           2
#  267              194 2019-01-02        8  Camisa Gola V Linho           4
#  ...              ...        ...      ...                  ...         ...
#  100786         69846 2019-12-25        8        Short Estampa           2
#  100787         69846 2019-12-25        8        Tênis Estampa           5
#  100789         69850 2019-12-25        8        Calça Estampa           4
#  100963         69972 2019-12-26        8           Terno Liso           3
#  100964         69972 2019-12-26        8       Sapato Estampa           5
#
#          Valor Unitário  Valor Final               Loja
#  106                 60           60  Salvador Shopping
#  166                113          113  Salvador Shopping
#  183                114          570  Salvador Shopping
#  244                105          210  Salvador Shopping
#  267                145          580  Salvador Shopping
#  ...                ...          ...                ...
#  100786              96          192  Salvador Shopping
#  100787             256         1280  Salvador Shopping
#  100789             177          708  Salvador Shopping
#  100963             720         2160  Salvador Shopping
#  100964             358         1790  Salvador Shopping
#
#  [4030 rows x 8 columns],
#  'Rio Mar Shopping Fortaleza':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  5                  3 2019-01-02        9       Cinto Linho           1
#  22                18 2019-01-02        9    Camisa Estampa           1
#  33                27 2019-01-02        9       Sunga Linho           1
#  34                27 2019-01-02        9    Terno Listrado           2
#  48                36 2019-01-02        9     Meia Listrado           1
#  ...              ...        ...      ...               ...         ...
#  100691         69773 2019-12-25        9  Pulseira Estampa           1
#  100896         69930 2019-12-25        9     Polo Listrado           1
#  100897         69930 2019-12-25        9     Sunga Estampa           2
#  100944         69961 2019-12-25        9       Polo Xadrez           4
#  100990         69993 2019-12-26        9     Sapato Xadrez           1
#
#          Valor Unitário  Valor Final                        Loja
#  5                  248          248  Rio Mar Shopping Fortaleza
#  22                 113          113  Rio Mar Shopping Fortaleza
#  33                 149          149  Rio Mar Shopping Fortaleza
#  34                 709         1418  Rio Mar Shopping Fortaleza
#  48                  37           37  Rio Mar Shopping Fortaleza
#  ...                ...          ...                         ...
#  100691              87           87  Rio Mar Shopping Fortaleza
#  100896             149          149  Rio Mar Shopping Fortaleza
#  100897             120          240  Rio Mar Shopping Fortaleza
#  100944             142          568  Rio Mar Shopping Fortaleza
#  100990             368          368  Rio Mar Shopping Fortaleza
#
#  [4118 rows x 8 columns],
#  'Shopping Center Leste Aricanduva':         Código Venda       Data  ID Loja         Produto  Quantidade  \
#  11                 9 2019-01-02       10     Tênis Linho           1
#  12                 9 2019-01-02       10   Casaco Xadrez           2
#  35                29 2019-01-02       10      Gorro Liso           4
#  92                70 2019-01-02       10     Gorro Linho           2
#  93                70 2019-01-02       10    Cueca Xadrez           1
#  ...              ...        ...      ...             ...         ...
#  100884         69922 2019-12-25       10            Meia           1
#  100885         69922 2019-12-25       10     Cinto Linho           1
#  100886         69922 2019-12-25       10    Short Xadrez           2
#  100966         69975 2019-12-26       10   Cueca Estampa           5
#  100967         69975 2019-12-26       10  Bermuda Xadrez           1
#
#          Valor Unitário  Valor Final                              Loja
#  11                 294          294  Shopping Center Leste Aricanduva
#  12                 259          518  Shopping Center Leste Aricanduva
#  35                  92          368  Shopping Center Leste Aricanduva
#  92                 124          248  Shopping Center Leste Aricanduva
#  93                  60           60  Shopping Center Leste Aricanduva
#  ...                ...          ...                               ...
#  100884              30           30  Shopping Center Leste Aricanduva
#  100885             248          248  Shopping Center Leste Aricanduva
#  100886             100          200  Shopping Center Leste Aricanduva
#  100966              66          330  Shopping Center Leste Aricanduva
#  100967             155          155  Shopping Center Leste Aricanduva
#
#  [4093 rows x 8 columns],
#  'Ribeirão Shopping':         Código Venda       Data  ID Loja                Produto  Quantidade  \
#  81                62 2019-01-02       11  Camisa Gola V Estampa           1
#  82                62 2019-01-02       11        Chinelo Estampa           2
#  109               84 2019-01-02       11        Pulseira Xadrez           5
#  110               84 2019-01-02       11            Sapato Liso           3
#  111               84 2019-01-02       11                  Calça           1
#  ...              ...        ...      ...                    ...         ...
#  100953         69967 2019-12-25       11                  Short           1
#  100954         69967 2019-12-25       11          Bermuda Linho           1
#  100983         69984 2019-12-26       11             Cueca Liso           4
#  100997         69997 2019-12-26       11        Camisa Listrado           1
#  100998         69997 2019-12-26       11            Short Linho           2
#
#          Valor Unitário  Valor Final               Loja
#  81                 118          118  Ribeirão Shopping
#  82                  74          148  Ribeirão Shopping
#  109                 87          435  Ribeirão Shopping
#  110                368         1104  Ribeirão Shopping
#  111                170          170  Ribeirão Shopping
#  ...                ...          ...                ...
#  100953              90           90  Ribeirão Shopping
#  100954             195          195  Ribeirão Shopping
#  100983              69          276  Ribeirão Shopping
#  100997             108          108  Ribeirão Shopping
#  100998             133          266  Ribeirão Shopping
#
#  [4048 rows x 8 columns],
#  'Shopping Morumbi':         Código Venda       Data  ID Loja         Produto  Quantidade  \
#  98                72 2019-01-02       12   Gorro Estampa           2
#  99                72 2019-01-02       12   Sapato Xadrez           4
#  102               75 2019-01-02       12   Sapato Xadrez           2
#  103               75 2019-01-02       12           Cueca           2
#  114               88 2019-01-02       12  Gorro Listrado           1
#  ...              ...        ...      ...             ...         ...
#  100818         69877 2019-12-25       12     Polo Xadrez           2
#  100819         69877 2019-12-25       12            Polo           1
#  100855         69904 2019-12-25       12      Polo Linho           1
#  100856         69904 2019-12-25       12  Gorro Listrado           3
#  100898         69931 2019-12-25       12      Gorro Liso           3
#
#          Valor Unitário  Valor Final              Loja
#  98                  93          186  Shopping Morumbi
#  99                 368         1472  Shopping Morumbi
#  102                368          736  Shopping Morumbi
#  103                 50          100  Shopping Morumbi
#  114                 97           97  Shopping Morumbi
#  ...                ...          ...               ...
#  100818             142          284  Shopping Morumbi
#  100819             130          130  Shopping Morumbi
#  100855             176          176  Shopping Morumbi
#  100856              97          291  Shopping Morumbi
#  100898              92          276  Shopping Morumbi
#
#  [3960 rows x 8 columns],
#  'Parque Dom Pedro Shopping':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  27                22 2019-01-02       13              Meia           1
#  28                22 2019-01-02       13        Meia Linho           2
#  29                22 2019-01-02       13        Calça Liso           2
#  46                35 2019-01-02       13           Relógio           2
#  47                35 2019-01-02       13            Sapato           2
#  ...              ...        ...      ...               ...         ...
#  100722         69796 2019-12-25       13        Tênis Liso           4
#  100729         69804 2019-12-25       13  Camiseta Estampa           1
#  100730         69804 2019-12-25       13      Camisa Linho           3
#  100808         69871 2019-12-25       13   Chinelo Estampa           1
#  100919         69943 2019-12-25       13    Relógio Xadrez           1
#
#          Valor Unitário  Valor Final                       Loja
#  27                  30           30  Parque Dom Pedro Shopping
#  28                  78          156  Parque Dom Pedro Shopping
#  29                 190          380  Parque Dom Pedro Shopping
#  46                 200          400  Parque Dom Pedro Shopping
#  47                 350          700  Parque Dom Pedro Shopping
#  ...                ...          ...                        ...
#  100722             266         1064  Parque Dom Pedro Shopping
#  100729             196          196  Parque Dom Pedro Shopping
#  100730             141          423  Parque Dom Pedro Shopping
#  100808              74           74  Parque Dom Pedro Shopping
#  100919             214          214  Parque Dom Pedro Shopping
#
#  [3902 rows x 8 columns],
#  'Bourbon Shopping SP':         Código Venda       Data  ID Loja          Produto  Quantidade  \
#  20                14 2019-01-02       14      Casaco Liso           2
#  126               99 2019-01-02       14    Sapato Xadrez           2
#  127               99 2019-01-02       14       Short Liso           5
#  128               99 2019-01-02       14   Cinto Listrado           4
#  143              110 2019-01-02       14     Polo Estampa           2
#  ...              ...        ...      ...              ...         ...
#  100832         69889 2019-12-25       14          Mochila           1
#  100899         69932 2019-12-25       14  Camiseta Xadrez           3
#  100927         69953 2019-12-25       14             Polo           5
#  100928         69953 2019-12-25       14            Tênis           1
#  100987         69987 2019-12-26       14  Bermuda Estampa           4
#
#          Valor Unitário  Valor Final                 Loja
#  20                 255          510  Bourbon Shopping SP
#  126                368          736  Bourbon Shopping SP
#  127                108          540  Bourbon Shopping SP
#  128                214          856  Bourbon Shopping SP
#  143                138          276  Bourbon Shopping SP
#  ...                ...          ...                  ...
#  100832             270          270  Bourbon Shopping SP
#  100899             200          600  Bourbon Shopping SP
#  100927             130          650  Bourbon Shopping SP
#  100928             250          250  Bourbon Shopping SP
#  100987             169          676  Bourbon Shopping SP
#
#  [4116 rows x 8 columns],
#  'Palladium Shopping Curitiba':         Código Venda       Data  ID Loja             Produto  Quantidade  \
#  65                47 2019-01-02       15               Short           1
#  76                59 2019-01-02       15               Calça           2
#  87                66 2019-01-02       15              Casaco           4
#  88                66 2019-01-02       15      Camiseta Linho           1
#  120               94 2019-01-02       15     Relógio Estampa           4
#  ...              ...        ...      ...                 ...         ...
#  100811         69872 2019-12-25       15   Camiseta Listrado           1
#  100924         69947 2019-12-25       15  Camisa Gola V Liso           2
#  100931         69956 2019-12-25       15       Mochila Linho           1
#  100976         69980 2019-12-26       15        Casaco Linho           1
#  100982         69983 2019-12-26       15         Meia Xadrez           2
#
#          Valor Unitário  Valor Final                         Loja
#  65                  90           90  Palladium Shopping Curitiba
#  76                 170          340  Palladium Shopping Curitiba
#  87                 250         1000  Palladium Shopping Curitiba
#  88                 223          223  Palladium Shopping Curitiba
#  120                219          876  Palladium Shopping Curitiba
#  ...                ...          ...                          ...
#  100811             197          197  Palladium Shopping Curitiba
#  100924             118          236  Palladium Shopping Curitiba
#  100931             311          311  Palladium Shopping Curitiba
#  100976             299          299  Palladium Shopping Curitiba
#  100982              41           82  Palladium Shopping Curitiba
#
#  [4210 rows x 8 columns],
#  'Passei das Águas Shopping':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  13                10 2019-01-02       16   Camiseta Xadrez           2
#  14                10 2019-01-02       16        Cueca Liso           1
#  23                19 2019-01-02       16  Relógio Listrado           1
#  24                19 2019-01-02       16       Calça Linho           2
#  276              199 2019-01-02       16          Camiseta           2
#  ...              ...        ...      ...               ...         ...
#  100661         69745 2019-12-24       16          Camiseta           3
#  100798         69861 2019-12-25       16       Terno Linho           5
#  100799         69861 2019-12-25       16   Camiseta Xadrez           2
#  100911         69937 2019-12-25       16      Sunga Xadrez           5
#  100932         69957 2019-12-25       16   Bermuda Estampa           1
#
#          Valor Unitário  Valor Final                       Loja
#  13                 200          400  Passei das Águas Shopping
#  14                  69           69  Passei das Águas Shopping
#  23                 218          218  Passei das Águas Shopping
#  24                 211          422  Passei das Águas Shopping
#  276                180          360  Passei das Águas Shopping
#  ...                ...          ...                        ...
#  100661             180          540  Passei das Águas Shopping
#  100798             750         3750  Passei das Águas Shopping
#  100799             200          400  Passei das Águas Shopping
#  100911             116          580  Passei das Águas Shopping
#  100932             169          169  Passei das Águas Shopping
#
#  [4000 rows x 8 columns],
#  'Center Shopping Uberlândia':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  30                23 2019-01-02       17   Bermuda Estampa           3
#  31                23 2019-01-02       17      Chinelo Liso           3
#  85                65 2019-01-02       17    Gorro Listrado           1
#  86                65 2019-01-02       17      Gorro Xadrez           1
#  104               80 2019-01-02       17        Meia Linho           3
#  ...              ...        ...      ...               ...         ...
#  100988         69991 2019-12-26       17           Mochila           4
#  100989         69991 2019-12-26       17   Camiseta Xadrez           1
#  100994         69996 2019-12-26       17    Short Listrado           2
#  100995         69996 2019-12-26       17           Mochila           4
#  100996         69996 2019-12-26       17  Pulseira Estampa           1
#
#          Valor Unitário  Valor Final                        Loja
#  30                 169          507  Center Shopping Uberlândia
#  31                  71          213  Center Shopping Uberlândia
#  85                  97           97  Center Shopping Uberlândia
#  86                  85           85  Center Shopping Uberlândia
#  104                 78          234  Center Shopping Uberlândia
#  ...                ...          ...                         ...
#  100988             270         1080  Center Shopping Uberlândia
#  100989             200          200  Center Shopping Uberlândia
#  100994             102          204  Center Shopping Uberlândia
#  100995             270         1080  Center Shopping Uberlândia
#  100996              87           87  Center Shopping Uberlândia
#
#  [4013 rows x 8 columns],
#  'Shopping Recife':         Código Venda       Data  ID Loja           Produto  Quantidade  \
#  15                11 2019-01-02       18          Camiseta           1
#  16                11 2019-01-02       18    Calça Listrado           2
#  17                11 2019-01-02       18    Camisa Estampa           1
#  61                45 2019-01-02       18      Camisa Linho           1
#  122               96 2019-01-02       18       Meia Xadrez           1
#  ...              ...        ...      ...               ...         ...
#  100891         69925 2019-12-25       18        Gorro Liso           2
#  100910         69936 2019-12-25       18       Terno Linho           1
#  100961         69971 2019-12-26       18        Cinto Liso           2
#  100962         69971 2019-12-26       18  Bermuda Listrado           2
#  100981         69982 2019-12-26       18     Mochila Linho           2
#
#          Valor Unitário  Valor Final             Loja
#  15                 180          180  Shopping Recife
#  16                 181          362  Shopping Recife
#  17                 113          113  Shopping Recife
#  61                 141          141  Shopping Recife
#  122                 41           41  Shopping Recife
#  ...                ...          ...              ...
#  100891              92          184  Shopping Recife
#  100910             750          750  Shopping Recife
#  100961             209          418  Shopping Recife
#  100962             163          326  Shopping Recife
#  100981             311          622  Shopping Recife
#
#  [3891 rows x 8 columns],
#  'Shopping Vila Velha':         Código Venda       Data  ID Loja         Produto  Quantidade  \
#  40                32 2019-01-02       19       Polo Liso           1
#  41                32 2019-01-02       19   Polo Listrado           2
#  49                38 2019-01-02       19     Meia Xadrez           3
#  50                38 2019-01-02       19         Relógio           1
#  107               82 2019-01-02       19   Meia Listrado           1
#  ...              ...        ...      ...             ...         ...
#  100726         69801 2019-12-25       19         Bermuda           3
#  100795         69859 2019-12-25       19       Meia Liso           2
#  100960         69970 2019-12-26       19    Casaco Linho           2
#  100965         69974 2019-12-26       19   Meia Listrado           3
#  100984         69985 2019-12-26       19  Pulseira Linho           2
#
#          Valor Unitário  Valor Final                 Loja
#  40                 137          137  Shopping Vila Velha
#  41                 149          298  Shopping Vila Velha
#  49                  41          123  Shopping Vila Velha
#  50                 200          200  Shopping Vila Velha
#  107                 37           37  Shopping Vila Velha
#  ...                ...          ...                  ...
#  100726             150          450  Shopping Vila Velha
#  100795              38           76  Shopping Vila Velha
#  100960             299          598  Shopping Vila Velha
#  100965              37          111  Shopping Vila Velha
#  100984             114          228  Shopping Vila Velha
#
#  [4234 rows x 8 columns],
#  'Shopping SP Market':         Código Venda       Data  ID Loja         Produto  Quantidade  \
#  74                56 2019-01-02       20     Gorro Linho           3
#  77                60 2019-01-02       20    Casaco Linho           3
#  78                60 2019-01-02       20       Polo Liso           5
#  89                67 2019-01-02       20      Polo Linho           3
#  131              101 2019-01-02       20  Cinto Listrado           2
#  ...              ...        ...      ...             ...         ...
#  100941         69960 2019-12-25       20            Polo           2
#  100942         69960 2019-12-25       20     Sapato Liso           1
#  100943         69960 2019-12-25       20  Sapato Estampa           3
#  100958         69969 2019-12-25       20   Pulseira Liso           1
#  100959         69969 2019-12-25       20   Camiseta Liso           2
#
#          Valor Unitário  Valor Final                Loja
#  74                 124          372  Shopping SP Market
#  77                 299          897  Shopping SP Market
#  78                 137          685  Shopping SP Market
#  89                 176          528  Shopping SP Market
#  131                214          428  Shopping SP Market
#  ...                ...          ...                 ...
#  100941             130          260  Shopping SP Market
#  100942             368          368  Shopping SP Market
#  100943             358         1074  Shopping SP Market
#  100958              87           87  Shopping SP Market
#  100959             187          374  Shopping SP Market
#
#  [4080 rows x 8 columns],
#  'Shopping Eldorado':         Código Venda       Data  ID Loja         Produto  Quantidade  \
#  36                31 2019-01-02       21  Casaco Estampa           3
#  37                31 2019-01-02       21        Pulseira           3
#  38                31 2019-01-02       21     Gorro Linho           1
#  39                31 2019-01-02       21     Cinto Linho           3
#  51                40 2019-01-02       21   Bermuda Linho           1
#  ...              ...        ...      ...             ...         ...
#  100935         69959 2019-12-25       21       Polo Liso           4
#  100936         69959 2019-12-25       21    Camisa Linho           3
#  100937         69959 2019-12-25       21    Cueca Xadrez           1
#  100985         69986 2019-12-26       21   Cueca Estampa           4
#  100986         69986 2019-12-26       21  Terno Listrado           3
#
#          Valor Unitário  Valor Final               Loja
#  36                 256          768  Shopping Eldorado
#  37                  70          210  Shopping Eldorado
#  38                 124          124  Shopping Eldorado
#  39                 248          744  Shopping Eldorado
#  51                 195          195  Shopping Eldorado
#  ...                ...          ...                ...
#  100935             137          548  Shopping Eldorado
#  100936             141          423  Shopping Eldorado
#  100937              60           60  Shopping Eldorado
#  100985              66          264  Shopping Eldorado
#  100986             709         2127  Shopping Eldorado
#
#  [4002 rows x 8 columns],
#  'Shopping Ibirapuera':         Código Venda       Data  ID Loja                Produto  Quantidade  \
#  7                  6 2019-01-02       22          Polo Listrado           4
#  58                44 2019-01-02       22                  Calça           2
#  59                44 2019-01-02       22        Camisa Listrado           1
#  60                44 2019-01-02       22            Camisa Liso           2
#  90                69 2019-01-02       22            Meia Xadrez           1
#  ...              ...        ...      ...                    ...         ...
#  100820         69880 2019-12-25       22         Mochila Xadrez           2
#  100917         69941 2019-12-25       22             Cueca Liso           5
#  100922         69946 2019-12-25       22           Calça Xadrez           1
#  100923         69946 2019-12-25       22           Gorro Xadrez           1
#  100970         69977 2019-12-26       22  Camisa Gola V Estampa           1
#
#          Valor Unitário  Valor Final                 Loja
#  7                  149          596  Shopping Ibirapuera
#  58                 170          340  Shopping Ibirapuera
#  59                 108          108  Shopping Ibirapuera
#  60                 105          210  Shopping Ibirapuera
#  90                  41           41  Shopping Ibirapuera
#  ...                ...          ...                  ...
#  100820             283          566  Shopping Ibirapuera
#  100917              69          345  Shopping Ibirapuera
#  100922             185          185  Shopping Ibirapuera
#  100923              85           85  Shopping Ibirapuera
#  100970             118          118  Shopping Ibirapuera
#
#  [4051 rows x 8 columns],
#  'Novo Shopping Ribeirão Preto':         Código Venda       Data  ID Loja                 Produto  Quantidade  \
#  53                41 2019-01-02       23                   Gorro           1
#  54                41 2019-01-02       23            Short Xadrez           4
#  79                61 2019-01-02       23  Camisa Gola V Listrado           1
#  80                61 2019-01-02       23          Camisa Estampa           2
#  118               93 2019-01-02       23           Camiseta Liso           1
#  ...              ...        ...      ...                     ...         ...
#  100978         69981 2019-12-26       23        Camiseta Estampa           1
#  100979         69981 2019-12-26       23              Meia Linho           1
#  100980         69981 2019-12-26       23          Sunga Listrado           2
#  100992         69995 2019-12-26       23          Cinto Listrado           3
#  100993         69995 2019-12-26       23                 Mochila           4
#
#          Valor Unitário  Valor Final                          Loja
#  53                  80           80  Novo Shopping Ribeirão Preto
#  54                 100          400  Novo Shopping Ribeirão Preto
#  79                 116          116  Novo Shopping Ribeirão Preto
#  80                 113          226  Novo Shopping Ribeirão Preto
#  118                187          187  Novo Shopping Ribeirão Preto
#  ...                ...          ...                           ...
#  100978             196          196  Novo Shopping Ribeirão Preto
#  100979              78           78  Novo Shopping Ribeirão Preto
#  100980             114          228  Novo Shopping Ribeirão Preto
#  100992             214          642  Novo Shopping Ribeirão Preto
#  100993             270         1080  Novo Shopping Ribeirão Preto
#
#  [4049 rows x 8 columns],
#  'Iguatemi Campinas':         Código Venda       Data  ID Loja          Produto  Quantidade  \
#  10                 8 2019-01-02       24    Terno Estampa           5
#  21                17 2019-01-02       24     Chinelo Liso           1
#  195              143 2019-01-02       24         Pulseira           3
#  230              166 2019-01-02       24     Cinto Xadrez           1
#  243              176 2019-01-02       24   Cinto Listrado           1
#  ...              ...        ...      ...              ...         ...
#  100904         69934 2019-12-25       24  Chinelo Estampa           3
#  100905         69934 2019-12-25       24    Camisa Xadrez           2
#  100906         69934 2019-12-25       24       Tênis Liso           2
#  100907         69934 2019-12-25       24  Casaco Listrado           1
#  100912         69939 2019-12-25       24     Bermuda Liso           5
#
#          Valor Unitário  Valor Final               Loja
#  10                 706         3530  Iguatemi Campinas
#  21                  71           71  Iguatemi Campinas
#  195                 70          210  Iguatemi Campinas
#  230                215          215  Iguatemi Campinas
#  243                214          214  Iguatemi Campinas
#  ...                ...          ...                ...
#  100904              74          222  Iguatemi Campinas
#  100905             105          210  Iguatemi Campinas
#  100906             266          532  Iguatemi Campinas
#  100907             269          269  Iguatemi Campinas
#  100912             157          785  Iguatemi Campinas
#
#  [4108 rows x 8 columns],
#  'Shopping Barra':         Código Venda       Data  ID Loja             Produto  Quantidade  \
#  6                  5 2019-01-02       25               Calça           1
#  70                52 2019-01-02       25      Gorro Listrado           4
#  129              100 2019-01-02       25  Camisa Gola V Liso           3
#  130              100 2019-01-02       25        Cinto Xadrez           4
#  172              132 2019-01-02       25         Terno Linho           2
#  ...              ...        ...      ...                 ...         ...
#  100865         69908 2019-12-25       25           Meia Liso           2
#  100866         69908 2019-12-25       25              Camisa           1
#  100874         69913 2019-12-25       25               Gorro           1
#  100875         69913 2019-12-25       25         Cinto Linho           1
#  100925         69950 2019-12-25       25         Cinto Linho           1
#
#          Valor Unitário  Valor Final            Loja
#  6                  170          170  Shopping Barra
#  70                  97          388  Shopping Barra
#  129                118          354  Shopping Barra
#  130                215          860  Shopping Barra
#  172                750         1500  Shopping Barra
#  ...                ...          ...             ...
#  100865              38           76  Shopping Barra
#  100866             100          100  Shopping Barra
#  100874              80           80  Shopping Barra
#  100875             248          248  Shopping Barra
#  100925             248          248  Shopping Barra
#
#  [3962 rows x 8 columns]}

# %%
# Pega o dia mais recente
dia_indicador = vendas['Data'].max()
print(dia_indicador)
# Out:
# 2019-12-26 00:00:00

# %% [markdown]
# ### Passo 3 - Salvar a planilha na pasta de backup

# %%
# Identificar se a pasta já existe
caminho_backup = pathlib.Path(r'backup-arquivos-lojas')
arquivos_pasta_backup = caminho_backup.iterdir()

lista_nomes_backup = [arquivo.name for arquivo in arquivos_pasta_backup]

for loja in dicionario_lojas:
    if loja not in lista_nomes_backup:
        nova_pasta = caminho_backup / loja
        nova_pasta.mkdir()
    
    # Salvar dentro da pasta
    nome_arquivo = f'{dia_indicador.month}_{dia_indicador.day}_{loja}.xlsx'
    local_arquivo = caminho_backup / loja / nome_arquivo
    dicionario_lojas[loja].to_excel(local_arquivo)

# %% [markdown]
# ### Passo 4 - Calcular o indicador para 1 loja
# ### Passo 5 - Enviar por e-mail para o gerente
# ### Passo 6 - Automatizar todas as lojas

# %%
# Definição de metas
meta_faturamento_dia = 1000
meta_faturamento_ano = 1650000
meta_qtdeprodutos_dia = 4
meta_qtdeprodutos_ano = 120
media_ticketmedio_dia = 500
media_ticketmedio_ano = 500

# %%
for loja in dicionario_lojas:

    vendas_loja = dicionario_lojas[loja]
    vendas_loja_dia = vendas_loja.loc[vendas_loja['Data']==dia_indicador, :]

    # Faturamento
    faturamento_ano = vendas_loja['Valor Final'].sum()
    #print(faturamento_ano)
    faturamento_dia = vendas_loja_dia['Valor Final'].sum()
    #print(faturamento_dia)

    # Diversidade de produtos
    qtde_produtos_ano = len(vendas_loja['Produto'].unique())
    #print(qtde_produtos_ano)
    qtde_produtos_dia = len(vendas_loja_dia['Produto'].unique())
    #print(qtde_produtos_dia)

    # Ticket medio
    valor_venda = vendas_loja[['Código Venda', 'ID Loja', 'Quantidade', 'Valor Unitário', 'Valor Final']].groupby('Código Venda').sum()
    ticket_medio_ano = valor_venda['Valor Final'].mean()
    #print(ticket_medio_ano)

    valor_venda_dia = vendas_loja_dia[['Código Venda', 'ID Loja', 'Quantidade', 'Valor Unitário', 'Valor Final']].groupby('Código Venda').sum()
    ticket_medio_dia = valor_venda_dia['Valor Final'].mean()
    #print(ticket_medio_dia)


    # Enviar o e-mail
    # Informações básicas
    nome = emails.loc[emails['Loja']==loja, 'Gerente'].values[0]
    EMAIL_REMETENTE = ''
    SENHA = ''  # Use senha de app
    EMAIL_DESTINO = emails.loc[emails['Loja']==loja, 'E-mail'].values[0]
    CAMINHO_ARQUIVO = pathlib.Path.cwd() / caminho_backup / loja / f'{dia_indicador.month}_{dia_indicador.day}_{loja}.xlsx'  # Pode ser imagem, .csv etc.

    # Cria o e-mail
    msg = EmailMessage()
    msg['Subject'] = f'OnePage Dia {dia_indicador.day}/{dia_indicador.month} - Loja {loja}'
    msg['From'] = EMAIL_REMETENTE
    msg['To'] = EMAIL_DESTINO

    # Definir cores para para o cenário
    if faturamento_dia >= meta_faturamento_dia:
        cor_fat_dia = 'green'
    else:
        cor_fat_dia = 'red'

    if faturamento_ano >= meta_faturamento_ano:
        cor_fat_ano = 'green'
    else:
        cor_fat_ano = 'red'

    if qtde_produtos_dia >= meta_qtdeprodutos_dia:
        cor_qtde_dia = 'green'
    else:
        cor_qtde_dia = 'red'

    if qtde_produtos_ano >= meta_qtdeprodutos_ano:
        cor_qtde_ano = 'green'
    else:
        cor_qtde_ano = 'red'

    if ticket_medio_dia >= media_ticketmedio_dia:
        cor_ticket_dia = 'green'
    else:
        cor_ticket_dia = 'red'

    if ticket_medio_ano >= media_ticketmedio_ano:
        cor_ticket_ano = 'green'
    else:
        cor_ticket_ano = 'red'

    # Corpo do email em html
    msg.add_alternative(
    f'''
    <p>Bom dia, {nome}</p>

    <p>O resultado de ontem <strong>({dia_indicador.day}/{dia_indicador.month})</strong> da Loja <strong>{loja}</strong> foi:</p>

    <table>
    <tr>
        <th>Indicador</th>
        <th>Valor Dia</th>
        <th>Meta Dia</th>
        <th>Cenário Dia</th>
    </tr>
    <tr>
        <td>Faturamento</td>
        <td style="text-align: center">R${faturamento_dia:.2f}</td>
        <td style="text-align: center">R${meta_faturamento_dia:.2f}</td>
        <td style="text-align: center"><font color="{cor_fat_dia}">◙</font></td>
    </tr>
    <tr>
        <td>Diversidade de Produtos</td>
        <td style="text-align: center">{qtde_produtos_dia}</td>
        <td style="text-align: center">{meta_qtdeprodutos_dia}</td>
        <td style="text-align: center"><font color="{cor_qtde_dia}">◙</font></td>
    </tr>
    <tr>
        <td>Ticket Médio</td>
        <td style="text-align: center">R${ticket_medio_dia:.2f}</td>
        <td style="text-align: center">R${media_ticketmedio_dia:.2f}</td>
        <td style="text-align: center"><font color="{cor_ticket_dia}">◙</font></td>
    </tr>
    </table>
    <br>
    <table>
    <tr>
        <th>Indicador</th>
        <th>Valor Ano</th>
        <th>Meta Ano</th>
        <th>Cenário Ano</th>
    </tr>
    <tr>
        <td>Faturamento</td>
        <td style="text-align: center">R${faturamento_ano:.2f}</td>
        <td style="text-align: center">R${meta_faturamento_ano:.2f}</td>
        <td style="text-align: center"><font color="{cor_fat_ano}">◙</font></td>
    </tr>
    <tr>
        <td>Diversidade de Produtos</td>
        <td style="text-align: center">{qtde_produtos_ano}</td>
        <td style="text-align: center">{meta_qtdeprodutos_ano}</td>
        <td style="text-align: center"><font color="{cor_qtde_ano}">◙</font></td>
    </tr>
    <tr>
        <td>Ticket Médio</td>
        <td style="text-align: center">R${ticket_medio_ano:.2f}</td>
        <td style="text-align: center">R${media_ticketmedio_ano:.2f}</td>
        <td style="text-align: center"><font color="{cor_ticket_ano}">◙</font></td>
    </tr>
    </table>

    <p>Segue em anexo a planilha com todos os dados para mais detalhes.</p>

    <p>Qualquer dúvida estou à disposição</p>
    <p>Att., Mikelly</p>
    ''', subtype='html')

    # Detecta o tipo MIME do arquivo
    file_path = Path(CAMINHO_ARQUIVO)
    mime_type, _ = mimetypes.guess_type(file_path)
    mime_main, mime_sub = mime_type.split('/')

    # Lê e anexa o arquivo
    with open(file_path, 'rb') as f:
        msg.add_attachment(f.read(), maintype=mime_main, subtype=mime_sub, filename=file_path.name)

    # Envia o e-mail via Gmail SMTP
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
        smtp.login(EMAIL_REMETENTE, SENHA)
        smtp.send_message(msg)

    print(f"E-mail da loja {loja} enviado com sucesso.")
# Out:
# E-mail da loja Iguatemi Esplanada enviado com sucesso.
# E-mail da loja Shopping Midway Mall enviado com sucesso.
# E-mail da loja Norte Shopping enviado com sucesso.
# E-mail da loja Shopping Iguatemi Fortaleza enviado com sucesso.
# E-mail da loja Shopping União de Osasco enviado com sucesso.
# E-mail da loja Shopping Center Interlagos enviado com sucesso.
# E-mail da loja Rio Mar Recife enviado com sucesso.
# E-mail da loja Salvador Shopping enviado com sucesso.
# E-mail da loja Rio Mar Shopping Fortaleza enviado com sucesso.
# E-mail da loja Shopping Center Leste Aricanduva enviado com sucesso.
# E-mail da loja Ribeirão Shopping enviado com sucesso.
# E-mail da loja Shopping Morumbi enviado com sucesso.
# E-mail da loja Parque Dom Pedro Shopping enviado com sucesso.
# E-mail da loja Bourbon Shopping SP enviado com sucesso.
# E-mail da loja Palladium Shopping Curitiba enviado com sucesso.
# E-mail da loja Passei das Águas Shopping enviado com sucesso.
# E-mail da loja Center Shopping Uberlândia enviado com sucesso.
# E-mail da loja Shopping Recife enviado com sucesso.
# E-mail da loja Shopping Vila Velha enviado com sucesso.
# E-mail da loja Shopping SP Market enviado com sucesso.
# E-mail da loja Shopping Eldorado enviado com sucesso.
# E-mail da loja Shopping Ibirapuera enviado com sucesso.
# E-mail da loja Novo Shopping Ribeirão Preto enviado com sucesso.
# E-mail da loja Iguatemi Campinas enviado com sucesso.
# E-mail da loja Shopping Barra enviado com sucesso.

# %% [markdown]
# ### Passo 7 - Criar ranking para diretoria

# %%
faturamento_lojas = vendas.groupby('Loja')[['Valor Final']].sum()
faturamento_lojas_ano = faturamento_lojas.sort_values(by='Valor Final', ascending=False)
display(faturamento_lojas)

nome_arquivo = f'{dia_indicador.month}_{dia_indicador.day}_Ranking Anual.xlsx'
faturamento_lojas_ano.to_excel(rf'backup-arquivos-lojas/{nome_arquivo}')

vendas_dia = vendas.loc[vendas['Data']==dia_indicador, :]
faturamento_lojas_dia = vendas_dia.groupby('Loja')[['Valor Final']].sum()
faturamento_lojas_dia = faturamento_lojas_dia.sort_values(by='Valor Final', ascending=False)
display(faturamento_lojas_dia)

nome_arquivo = f'{dia_indicador.month}_{dia_indicador.day}_Ranking Dia.xlsx'
faturamento_lojas_dia.to_excel(rf'backup-arquivos-lojas/{nome_arquivo}')
# Out:
#                                   Valor Final
# Loja
# Bourbon Shopping SP                   1726110
# Center Shopping Uberlândia            1668921
# Iguatemi Campinas                     1762419
# Iguatemi Esplanada                    1699681
# Norte Shopping                        1711968
# Novo Shopping Ribeirão Preto          1678225
# Palladium Shopping Curitiba           1721120
# Parque Dom Pedro Shopping             1631630
# Passei das Águas Shopping             1649014
# Ribeirão Shopping                     1707122
# Rio Mar Recife                        1722766
# Rio Mar Shopping Fortaleza            1698430
# Salvador Shopping                     1646739
# Shopping Barra                        1653103
# Shopping Center Interlagos            1640486
# Shopping Center Leste Aricanduva      1682870
# Shopping Eldorado                     1648111
# Shopping Ibirapuera                   1635060
# Shopping Iguatemi Fortaleza           1674824
# Shopping Midway Mall                  1590441
# Shopping Morumbi                      1586444
# Shopping Recife                       1624879
# Shopping SP Market                    1721763
# Shopping União de Osasco              1663770
# Shopping Vila Velha                   1731167
#                                   Valor Final
# Loja
# Salvador Shopping                        3950
# Novo Shopping Ribeirão Preto             3400
# Center Shopping Uberlândia               2651
# Shopping Eldorado                        2391
# Shopping Center Interlagos               1582
# Shopping Recife                          1366
# Norte Shopping                           1259
# Shopping União de Osasco                 1207
# Shopping Vila Velha                       937
# Bourbon Shopping SP                       676
# Ribeirão Shopping                         650
# Shopping Center Leste Aricanduva          485
# Palladium Shopping Curitiba               381
# Rio Mar Shopping Fortaleza                368
# Shopping Midway Mall                      170
# Shopping Ibirapuera                       118

# %% [markdown]
# ### Passo 8 - Enviar e-mail para diretoria

# %%
# Enviar o e-mail para diretoria
# Informações básicas
EMAIL_REMETENTE = ''
SENHA = ''  # Use senha de app
EMAIL_DESTINO = emails.loc[emails['Loja']=='Diretoria', 'E-mail'].values[0]
CAMINHO_ARQUIVO_RANKING_DIA = pathlib.Path.cwd() / caminho_backup / f'{dia_indicador.month}_{dia_indicador.day}_Ranking Dia.xlsx'  # Pode ser imagem, .csv etc.
CAMINHO_ARQUIVO_RANKING_ANUAL = pathlib.Path.cwd() / caminho_backup / f'{dia_indicador.month}_{dia_indicador.day}_Ranking Anual.xlsx'  # Pode ser imagem, .csv etc.

# Cria o e-mail
msg = EmailMessage()
msg['Subject'] = f'Ranking Dia {dia_indicador.day}/{dia_indicador.month}'
msg['From'] = EMAIL_REMETENTE
msg['To'] = EMAIL_DESTINO

# Corpo do email em html
msg.set_content(f'''
Prezados, bom dia

Melhor loja do Dia em Faturamento: Loja {faturamento_lojas_dia.index[0]} com Faturamento R${faturamento_lojas_dia.iloc[0, 0]:.2f}
Pior loja do Dia em Faturamento: Loja {faturamento_lojas_dia.index[-1]} com Faturamento R${faturamento_lojas_dia.iloc[-1, 0]:.2f}

Melhor loja do Ano em Faturamento: Loja {faturamento_lojas_ano.index[0]} com Faturamento R${faturamento_lojas_ano.iloc[0, 0]:.2f}
Pior loja do Ano em Faturamento: Loja {faturamento_lojas_ano.index[-1]} com Faturamento R${faturamento_lojas_ano.iloc[-1, 0]:.2f}

Segue em anexo os rankings do ano e do dia de todas as lojas.
Qualquer dúvida estou à disposição.

Att.,
Mikelly Lima.
''')

# Detecta o tipo MIME do arquivo
file_path1 = Path(CAMINHO_ARQUIVO_RANKING_DIA)
mime_type1, _ = mimetypes.guess_type(file_path)
mime_main1, mime_sub1 = mime_type.split('/')

file_path2 = Path(CAMINHO_ARQUIVO_RANKING_ANUAL)
mime_type2, _ = mimetypes.guess_type(file_path)
mime_main2, mime_sub2 = mime_type.split('/')


# Lê e anexa o arquivo
with open(file_path1, 'rb') as f:
    msg.add_attachment(f.read(), maintype=mime_main1, subtype=mime_sub1, filename=file_path1.name)

# Lê e anexa o arquivo
with open(file_path2, 'rb') as f:
    msg.add_attachment(f.read(), maintype=mime_main2, subtype=mime_sub2, filename=file_path2.name)

# Envia o e-mail via Gmail SMTP
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
    smtp.login(EMAIL_REMETENTE, SENHA)
    smtp.send_message(msg)

print(f'E-mail da Diretoria enviado com sucesso.')
# Out:
# E-mail da Diretoria enviado com sucesso.
